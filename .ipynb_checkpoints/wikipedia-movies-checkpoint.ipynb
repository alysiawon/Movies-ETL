# %% [markdown]
# ## 8.2: Extract The Data

# %% [markdown]
# ### 8.2.1: Extract the Wikipedia Movies JSON

# %%
# Import Dependencies
import json
import pandas as pd
import numpy as np

# %%
# File Directory
file_dir = '/Users/alysiawon/Data Analytics Bootcamp/Unit 3 - Databases/Week 8 - ETL/Challenge/Movies-ETL/'

f'{file_dir}wikipedia-movies.json'
# Out:
# '/Users/alysiawon/Data Analytics Bootcamp/Unit 3 - Databases/Week 8 - ETL/Challenge/Movies-ETL/wikipedia-movies.json'

# %%
# Open File
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
# Count How Many Records
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records
# wiki_movies_raw[:5]

# %%
# Last 5 records
# wiki_movies_raw[-5:]

# %%
# Some records in the middle
# wiki_movies_raw[3600:3605]

# %% [markdown]
# ### 8.2.2: Extract The Kaggle Data

# %%
# Open Files
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
# First 5 Rows
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection    budget  \
# 816    False                   NaN         0
# 42543  False                   NaN         0
# 111    False                   NaN  35000000
# 11749  False                   NaN         0
# 4247   False                   NaN         0
#
#                                                   genres homepage      id  \
# 816    [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...      NaN   18862
# 42543  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...      NaN  377362
# 111    [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN   43566
# 11749                      [{'id': 18, 'name': 'Drama'}]      NaN  118536
# 4247   [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...      NaN   21488
#
#          imdb_id original_language                           original_title  \
# 816    tt0116571                en                             House Arrest
# 42543  tt3170624                pt  Clarisse ou alguma coisa sobre nós dois
# ...

# %% [markdown]
# ## 8.3: Clean Individual Datasets

# %% [markdown]
# ### 8.3.1: Data-Cleaning Strategies

# %%
# Analyzing Data

wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head(5)
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
# View Columns

wiki_movies_df.columns.to_list()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...
